# %% [markdown]
# ## Q1 - Use the API to get all available data for the _GDP per capita, PPP (constant 2017 international $)_ indicator. Hint: this indicator has code "NY.GDP.PCAP.PP.KD". Adjust the query parameters so that you can retrieve all available rows. Convert the results to a DataFrame.

# %%
import requests
import matplotlib.pyplot as plt
import pandas as pd

# %%
#endpoint = 'https://data.worldbank.org/indicator/NY.GDP.PCAP.PP.KD'
endpoint_gdp = 'https://api.worldbank.org/v2/country/all/indicator/NY.GDP.PCAP.PP.KD?format=json'

response_gdp = requests.get(endpoint_gdp)

# %%
response_gdp
# Out:
# <Response [200]>

# %%
#endpoint = 'https://data.worldbank.org/indicator/NY.GDP.PCAP.PP.KD'
endpoint_gdp = 'https://api.worldbank.org/v2/country/all/indicator/NY.GDP.PCAP.PP.KD?format=json'
params_gdp = {
    'date': '2017'
}

response_gdp = requests.get(endpoint_gdp, params = params_gdp)

response_gdp.text
# Out:
# '[{"page":1,"pages":6,"per_page":50,"total":266,"sourceid":"2","lastupdated":"2025-04-15"},[{"indicator":{"id":"NY.GDP.PCAP.PP.KD","value":"GDP per capita, PPP (constant 2021 international $)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2017","value":4085.879142873,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.PCAP.PP.KD","value":"GDP per capita, PPP (constant 2021 international $)"},"country":{"id":"ZI","value":"Africa Western and Central"},"countryiso3code":"AFW","date":"2017","value":4709.64546122443,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.PCAP.PP.KD","value":"GDP per capita, PPP (constant 2021 international $)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"ARB","date":"2017","value":16054.9758759011,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"NY.GDP.PCAP.PP.KD","value":"GDP per capita, PPP (constant 2021 international $)"},"country":{"id":"S3","value":"Ca
# ...

# %%
res_gdp = response_gdp.json()

# %%
pd.DataFrame(res_gdp[1])
# Out:
#                                             indicator  \
# 0   {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 1   {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 2   {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 3   {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 4   {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 5   {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 6   {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 7   {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 8   {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 9   {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 10  {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 11  {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 12  {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 13  {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 14  {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# 15  {'id': 'NY.GDP.PCAP.PP.KD', 'value': 'GDP per ...
# ...

# %%
pd.json_normalize(res_gdp[1])
# Out:
#    countryiso3code  date         value unit obs_status  decimal  \
# 0              AFE  2017   4085.879143                        0
# 1              AFW  2017   4709.645461                        0
# 2              ARB  2017  16054.975876                        0
# 3              CSS  2017  19132.939321                        0
# 4              CEB  2017  34797.358384                        0
# 5              EAR  2017  10144.520572                        0
# 6              EAS  2017  18498.869544                        0
# 7              EAP  2017  14861.366454                        0
# 8              TEA  2017  15028.621872                        0
# 9              EMU  2017  52775.602422                        0
# 10             ECS  2017  40214.666652                        0
# 11             ECA  2017  19704.175098                        0
# 12             TEC  2017  27012.731793                        0
# 13             EUU  2017  49618.728580                        0
# ...

# %% [markdown]
# ## Q2 - Now, use the API to get all available data for _Life expectancy at birth, total (years)_. This indicator has code "SP.DYN.LE00.IN". Again, convert the results to a DataFrame.

# %%
endpoint_life = 'https://api.worldbank.org/v2/country/all/indicator/SP.DYN.LE00.IN?format=json'
params_life = {
    'date': '2017'
}

response_life = requests.get(endpoint_life, params = params_life)

response_life.text
# Out:
# '[{"page":1,"pages":6,"per_page":50,"total":266,"sourceid":"2","lastupdated":"2025-04-15"},[{"indicator":{"id":"SP.DYN.LE00.IN","value":"Life expectancy at birth, total (years)"},"country":{"id":"ZH","value":"Africa Eastern and Southern"},"countryiso3code":"AFE","date":"2017","value":62.5912750961501,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SP.DYN.LE00.IN","value":"Life expectancy at birth, total (years)"},"country":{"id":"ZI","value":"Africa Western and Central"},"countryiso3code":"AFW","date":"2017","value":56.6264388112566,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SP.DYN.LE00.IN","value":"Life expectancy at birth, total (years)"},"country":{"id":"1A","value":"Arab World"},"countryiso3code":"ARB","date":"2017","value":71.1128560080647,"unit":"","obs_status":"","decimal":0},{"indicator":{"id":"SP.DYN.LE00.IN","value":"Life expectancy at birth, total (years)"},"country":{"id":"S3","value":"Caribbean small states"},"countryiso3code":"CSS","date":"201
# ...

# %%
res_life = response_life.json()

# %%
pd.DataFrame(res_life[1])
# Out:
#                                             indicator  \
# 0   {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 1   {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 2   {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 3   {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 4   {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 5   {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 6   {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 7   {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 8   {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 9   {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 10  {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 11  {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 12  {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 13  {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 14  {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# 15  {'id': 'SP.DYN.LE00.IN', 'value': 'Life expect...
# ...

# %%
pd.json_normalize(res_life[1])
# Out:
#    countryiso3code  date      value unit obs_status  decimal    indicator.id  \
# 0              AFE  2017  62.591275                        0  SP.DYN.LE00.IN
# 1              AFW  2017  56.626439                        0  SP.DYN.LE00.IN
# 2              ARB  2017  71.112856                        0  SP.DYN.LE00.IN
# 3              CSS  2017  71.807567                        0  SP.DYN.LE00.IN
# 4              CEB  2017  76.923712                        0  SP.DYN.LE00.IN
# 5              EAR  2017  70.272995                        0  SP.DYN.LE00.IN
# 6              EAS  2017  76.078992                        0  SP.DYN.LE00.IN
# 7              EAP  2017  75.239671                        0  SP.DYN.LE00.IN
# 8              TEA  2017  75.267164                        0  SP.DYN.LE00.IN
# 9              EMU  2017  81.885991                        0  SP.DYN.LE00.IN
# 10             ECS  2017  77.901611                        0  SP.DYN.LE00.IN
# ...

# %% [markdown]
# ## Q3 - Merge the two results DataFrames together. You may want to rename or drop columns prior to merging.
